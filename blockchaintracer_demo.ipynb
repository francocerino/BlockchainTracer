# %%
from blockchaintracer import BlockchainTracer

# %%
bt = BlockchainTracer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 bt = BlockchainTracer()
#
# TypeError: __init__() missing 1 required positional argument: 'provider_url'
